# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('features_3_sec.csv')

# %%
data.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
dataset = data[data['label'].isin(['blues', 'classical', 'jazz', 'metal', 'pop'])].drop(['filename','length'],axis=1)
dataset.iloc[:, :-15].head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.335406         0.091048  0.130405  0.003521
# 1          0.343065         0.086147  0.112699  0.001450
# 2          0.346815         0.092243  0.132003  0.004620
# 3          0.363639         0.086856  0.132565  0.002448
# 4          0.335579         0.088129  0.143289  0.001701
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1773.065032          167541.630869              1972.744388
# 1             1816.693777           90525.690866              2010.051501
# 2             1788.539719          111407.437613              2084.565132
# 3             1655.289045          111952.284517              1960.039988
# 4             1630.656199           79667.267654              1948.503884
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc9_mean  \
# 0           117335.771563   3714.560359  1.080790e+06  ...  -14.633434
# 1            65671.875673   3869.682242  6.722448e+05  ...  -12.465918
# 2            75124.921716   3997.639160  7.907127e+05  ...  -13.216637
# 3            82913.639269   3568.300218  9.216524e+05  ...  -13.755463
# 4            60204.020268   3469.992864  6.102111e+05  ...  -18.274683
#
#     mfcc9_var  mfcc10_mean  mfcc10_var  mfcc11_mean  mfcc11_var  mfcc12_mean  \
# 0   83.437233    10.270527   97.001335    -9.708279   66.669891    10.183875
# 1   68.271523    17.898169   56.222176   -11.732554   54.373909     8.145000
# 2  120.308784    10.406025   35.757862    -7.991465   47.911613    11.853963
# 3   73.868576    12.993759   41.549564   -12.648887   58.540478    10.389314
# 4   95.300995    14.316693   58.821163    -5.792194   55.030254    17.045437
#
#    mfcc12_var  mfcc13_mean  mfcc13_var
# 0   45.103611    -4.681614   34.169498
# 1   40.662876    -7.717751   30.808521
# 2   36.569931    -4.677677   40.725075
# 3   39.102024    -4.362739   60.714748
# 4   43.229939    -5.681399   46.515259
#
# [5 rows x 43 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import preprocessing

# %%
y = LabelEncoder().fit_transform(dataset.iloc[:,-1])
y.shape
# Out:
# (4998,)

# %%
X = StandardScaler().fit_transform(np.array(dataset.iloc[:, :-15], dtype = float))
X.shape
# Out:
# (4998, 43)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=42)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (3498, 43) (3498,)
# Test set: (1500, 43) (1500,)

# %%
import tensorflow.keras as keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
# defining our regression model 
n_cols = dataset.iloc[:, :-15].shape[1]
def regression_model_1():
    # structure of our model
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(n_cols,)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu',))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(5,activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=10, 
                                            verbose=1, 
                                            )
Callbacks = [earlystop, learning_rate_reduction]

# %%
#build the model
# model_1 = regression_model_1()

#fit the model
# model_1.fit(X_train,y_train, callbacks=Callbacks , validation_data=(X_test,y_test) ,epochs=100,batch_size=150)
# Out:
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\user1\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3498 samples, validate on 1500 samples
# Epoch 1/100
# 3498/3498 [==============================] - 1s 373us/step - loss: 1.2033 - accuracy: 0.5500 - val_loss: 1.0132 - val_accuracy: 0.7307
# Epoch 2/100
# 3498/3498 [==============================] - 0s 66us/step - loss: 0.6223 - accuracy: 0.7722 - val_loss: 0.7441 - val_accuracy: 0.8280
# Epoch 3/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.4636 - accuracy: 0.8373 - val_loss: 0.5531 - val_accuracy: 0.8767
# Epoch 4/100
# 3498/3498 [==============================] - 0s 71us/step - loss: 0.3744 - accuracy: 0.8788 - val_loss: 0.4184 - val_accuracy: 0.9120
# Epoch 5/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.3301 - accuracy: 0.8931 - val_loss: 0.3305 - val_accuracy: 0.9220
# Epoch 6/100
# 3498/3498 [==============================] - 0s 69us/step - loss: 0.2888 - accuracy: 0.9031 - val_loss: 0.2724 - val_accuracy: 0.9287
# Epoch 7/100
# 3498/3498 [==============================] - 0s 68us/step - loss: 0.2696 - accuracy: 0.9142 - val_loss: 0.2410 - val_accuracy: 0.9260
# Epoch 8/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.2320 - accuracy: 0.9205 - val_loss: 0.2097 - val_accuracy: 0.9320
# Epoch 9/100
# 3498/3498 [==============================] - 0s 69us/step - loss: 0.2092 - accuracy: 0.9328 - val_loss: 0.1939 - val_accuracy: 0.9393
# Epoch 10/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1896 - accuracy: 0.9317 - val_loss: 0.1793 - val_accuracy: 0.9387
# Epoch 11/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1909 - accuracy: 0.9331 - val_loss: 0.1598 - val_accuracy: 0.9467
# Epoch 12/100
# 3498/3498 [==============================] - 0s 62us/step - loss: 0.1712 - accuracy: 0.9428 - val_loss: 0.1757 - val_accuracy: 0.9347
# Epoch 13/100
# 3498/3498 [==============================] - 0s 71us/step - loss: 0.1688 - accuracy: 0.9414 - val_loss: 0.1516 - val_accuracy: 0.9467
# Epoch 14/100
# 3498/3498 [==============================] - 0s 66us/step - loss: 0.1473 - accuracy: 0.9560 - val_loss: 0.1417 - val_accuracy: 0.9527
# Epoch 15/100
# 3498/3498 [==============================] - 0s 63us/step - loss: 0.1303 - accuracy: 0.9617 - val_loss: 0.1391 - val_accuracy: 0.9533
# Epoch 16/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1435 - accuracy: 0.9531 - val_loss: 0.1406 - val_accuracy: 0.9533
# Epoch 17/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1295 - accuracy: 0.9574 - val_loss: 0.1363 - val_accuracy: 0.9560
# Epoch 18/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1310 - accuracy: 0.9571 - val_loss: 0.1268 - val_accuracy: 0.9567
# Epoch 19/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1057 - accuracy: 0.9620 - val_loss: 0.1325 - val_accuracy: 0.9580
# Epoch 20/100
# 3498/3498 [==============================] - 0s 70us/step - loss: 0.1091 - accuracy: 0.9631 - val_loss: 0.1315 - val_accuracy: 0.9547
# Epoch 21/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.1013 - accuracy: 0.9686 - val_loss: 0.1397 - val_accuracy: 0.9547
# Epoch 22/100
# 3498/3498 [==============================] - 0s 65us/step - loss: 0.0962 - accuracy: 0.9677 - val_loss: 0.1291 - val_accuracy: 0.9607
# Epoch 23/100
# 3498/3498 [==============================] - 0s 67us/step - loss: 0.0956 - accuracy: 0.9694 - val_loss: 0.1331 - val_accuracy: 0.9607
# Epoch 24/100
# 3498/3498 [==============================] - 0s 66us/step - loss: 0.0918 - accuracy: 0.9688 - val_loss: 0.1335 - val_accuracy: 0.9593
# Epoch 25/100
# 3498/3498 [==============================] - 0s 63us/step - loss: 0.0798 - accuracy: 0.9757 - val_loss: 0.1402 - val_accuracy: 0.9540
# Epoch 26/100
# 3498/3498 [==============================] - 0s 70us/step - loss: 0.0831 - accuracy: 0.9723 - val_loss: 0.1324 - val_accuracy: 0.9573
# Epoch 27/100
# 3498/3498 [==============================] - 0s 64us/step - loss: 0.0684 - accuracy: 0.9791 - val_loss: 0.1380 - val_accuracy: 0.9613
# Epoch 28/100
# 3498/3498 [==============================] - 0s 65us/step - loss: 0.0738 - accuracy: 0.9737 - val_loss: 0.1406 - val_accuracy: 0.9560

# %%
# model_1.save('Keras_reg_3sec_5.h5')

# %%
from keras.models import load_model
model = load_model('Keras_reg_3sec_5.h5')
predictions = model.predict_classes(X_test)
score = model.evaluate(X_test,y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# accuracy: 95.60%
